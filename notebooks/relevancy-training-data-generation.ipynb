# %%
newsletter_descriptions = [
    "I want a newsletter about current Hollywood celebrity news and gossip.",
    "I want a newsletter about the space sector. I am not interested in scientific or technological advancements. I am mostly interested in space-sector financial and political news, like new laws, new startup initiatives, VC funding, etc.",
    "I am interested in a newsletter on Electric Vehicle news. I am mostly interested in the scientific discoveries that enable improvements in the vehicles.",
    "I want a newsletter focused on emerging trends in renewable energy, specifically solar and wind power.",
    "I'm looking for a newsletter about advancements in AI and machine learning, particularly in healthcare applications.",
    "I need a newsletter that covers the latest in cybersecurity threats and protection strategies for small businesses.",
    "I'm interested in a newsletter that provides updates on major infrastructure projects worldwide, like bridges, tunnels, and highways.",
    "I want a newsletter about the latest developments in virtual reality technology, especially in gaming and education.",
    "I'm looking for a newsletter that discusses new trends and techniques in digital marketing, with a focus on social media platforms.",
    "I need a newsletter that tracks the progress and challenges in the quest for Mars colonization.",
    "I'm interested in a newsletter about the impact of climate change on coastal cities and the measures being taken to mitigate it.",
    "I want a newsletter that covers breakthroughs in medical research, particularly in cancer treatment.",
    "I'm looking for a newsletter about the evolution of smart home technology and IoT devices.",
    "I need a newsletter focused on the global impact of blockchain technology beyond cryptocurrencies.",
    "I'm interested in a newsletter that provides insights into the future of transportation, including hyperloop and drone delivery systems.",
    "I want a newsletter about the changing landscape of the film industry, with a focus on independent filmmaking and streaming platforms.",
    "I'm looking for a newsletter that delves into sustainable fashion, covering eco-friendly materials and ethical manufacturing practices.",
    "I need a newsletter about the latest in agricultural technology and its role in addressing food security.",
    "I'm interested in a newsletter that covers the intersection of technology and education, focusing on e-learning platforms and digital classrooms.",
    "I want a newsletter about the developments in 3D printing technology, particularly in healthcare and construction."
]

# %%
from app.path_utils import root_path

data_folder_path = root_path() / ".." / ".." / "training-data" / "relevancy"

def write_to_newsletter_description_file(
    description: str, new_text: str, only_if_not_exist: bool = False
):
    if not data_folder_path.exists():
        data_folder_path.mkdir()
        
    description_hash = hash(description)
    description_file_path = data_folder_path / f"{description_hash}.txt"

    if not only_if_not_exist or not description_file_path.exists():
        with open(description_file_path, "a") as f:
            f.write(new_text)

# %%
for description in newsletter_descriptions:
    write_to_newsletter_description_file(
        description=description,
        new_text=f"DESCRIPTION: {description}",
        only_if_not_exist=True,
    )

# %%
import random

from app.core.newsletter_creator.newsletter_creator import (
    get_news_items
)
from app.core.newsletter_creator.utils import (
    get_article_selection_text,
    is_valid_candidate_item,
)
from app.schemas.newsletter_issue import NewsletterIssueCreate
from app.schemas.issue_metrics import IssueMetricsCreate
from app.cache.redis.aio_redis_cache import AioRedisCache
from app.cache.redis.redis_utils import redis_config
from app.core.api_provider import APIProvider
from app.core.data_processors.openai.openai import OpenAI
from app.core.data_processors.openai.openai_utils import (
    OpenAIModels,
    openai_config, call_openai_api_with_rate_limit_protection,
)
from app.core.newsletter_creator.newsletter_creator_utils import (
    newsletter_creator_config,
)
from app.core.selection_algos.representative_items_algo import (
    generate_most_representative_items,
)


async def generate_llm_training_prompts(description: str):
    description_hash = hash(description)
    
    api_provider_ = APIProvider()
    openai = OpenAI(api_provider=api_provider_, config=openai_config)
    cache = AioRedisCache(config=redis_config)

    await cache.initialize()
    
    news_items = await get_news_items(
        cache=cache, newsletter_issue_id=-1
    )

    newsletter_description_embedding = await call_openai_api_with_rate_limit_protection(
        newsletter_issue_id=-1,
        async_func=openai.get_embedding,
        model=OpenAIModels.TEXT_EMBEDDING_ADA_002,
        text=description,
    )

    representative_items_generator = generate_most_representative_items(
        target_vector=newsletter_description_embedding.vector,
        cache_items=news_items,
    )

    processed_articles = 0
    candidate_titles = []
    candidates = []

    async for item in representative_items_generator:
        if is_valid_candidate_item(
            newsletter_issue_id=-1,
            item=item,
            candidate_titles=candidate_titles,
        ):
            candidates.append(item)
            candidate_titles.append(item.article.title)
            if (
                len(candidate_titles)
                == newsletter_creator_config.max_processed_articles_per_newsletter
            ):
                break

    all_candidates_text = ""
    
    for candidate in candidates:
        article_selection_text = await get_article_selection_text(
            openai=openai,
            cache=cache,
            newsletter_issue_id=-1,
            item=candidate,
            in_issue=NewsletterIssueCreate(
                issue_id=0,
                subscription_id=0,
                timestamp=0,
                metrics=IssueMetricsCreate(
                    metrics_id="",
                    newsletter_generation_config_id=-1,
                    time_to_generate=-1,
                ),
            ),
        )
        
        relevancy_prompt = newsletter_creator_config.article_relevancy_prompt.format(
            newsletter_description=description,
            current_article_summary=article_selection_text,
        )

        all_candidates_text += (
            f"\n\nPROMPT:"
            f"\n\n{relevancy_prompt}"
            f"\n\nRESPONSE:"
            f"\n\nyes/no"
        )

    write_to_newsletter_description_file(
        description=description, new_text=all_candidates_text
    )
# Out:
# 2024-01-27 10:45:57,843 - passlib.utils.compat - DEBUG - loaded lazy attr 'SafeConfigParser': <class 'configparser.ConfigParser'>
# 2024-01-27 10:45:57,843 - passlib.utils.compat - DEBUG - loaded lazy attr 'NativeStringIO': <class '_io.StringIO'>
# 2024-01-27 10:45:57,844 - passlib.utils.compat - DEBUG - loaded lazy attr 'BytesIO': <class '_io.BytesIO'>
# 2024-01-27 10:45:57,851 - passlib.registry - DEBUG - registered 'bcrypt' handler: <class 'passlib.handlers.bcrypt.bcrypt'>

# %%
import asyncio

for description in newsletter_descriptions:
    await generate_llm_training_prompts(description=description)
# Out:
# 2024-01-27 10:46:42,469 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706240802.469415
# 2024-01-27 10:46:42,728 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:46:56,068 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12643 new items since 1706240802.469415
# 2024-01-27 10:46:59,176 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Super League news: Jonny Lomax confirmed as new St Helens captain following James Roby retirement
# Stay up to date with the latest rugby league news and gossip from Super League and beyond. - www.skysports.com
# 2024-01-27 10:46:59,177 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
#
- app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article How California is casting a cloud over residential solar
# 2024-01-27 10:50:36,705 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article U.S. agencies set plans to protect endangered right whales during offshore wind operations
# 2024-01-27 10:50:52,666 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article The Holdouts in the Quest for a Better Power Grid
# 2024-01-27 10:50:52,670 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241052.6700642
# 2024-01-27 10:50:53,104 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:51:04,374 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12614 new items since 1706241052.6700642
# 2024-01-27 10:51:05,058 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:51:05,058 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:51:17,823 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article AI Revolutionizes Patient Diagnostics with Google’s New AI Doctor AMIE
# 2024-01-27 10:52:15,418 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Native AI Introduces Lever To Control Synthetic Data Hallucination
# 2024-01-27 10:52:21,973 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Sell Our NHS Data for Edge in Global AI Competition Urge Blair and Hague
# 2024-01-27 10:52:21,976 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241141.976318
# 2024-01-27 10:52:22,403 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:52:33,629 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12609 new items since 1706241141.976318
# 2024-01-27 10:52:34,296 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:52:34,297 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:52:43,049 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article How to Read Leaked Datasets Like a Journalist
# 2024-01-27 10:52:59,089 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article QR Code Phishing: The Hidden Danger to Business Security
# 2024-01-27 10:52:59,091 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241179.091836
# 2024-01-27 10:52:59,548 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:53:12,526 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12601 new items since 1706241179.091836
# 2024-01-27 10:53:13,294 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# NI traffic alerts: Belfast road closed due to ongoing incident
# We’ll bring you all the latest traffic and travel information from across Northern Ireland.
# 2024-01-27 10:53:13,294 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# NI traffic alerts: Three people taken to hospital after Belfast crash
# We’ll bring you all the latest traffic and travel information from across Northern Ireland.
# 2024-01-27 10:53:13,295 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# NI traffic alerts: Roads reopen in Co Down as police warn of weekend disruption in Belfast
# We’ll bring you all the latest traffic and travel information from across Northern Ireland.
# 2024-01-27 10:53:13,296 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# NI traffic alerts: Separate crashes causing disruption in Co Down
# We’ll bring you all the latest traffic and travel information from across Northern Ireland.
# 2024-01-27 10:53:19,730 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article TVCA transport plans approved including town centre trams
# 2024-01-27 10:53:19,733 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241199.733485
# 2024-01-27 10:53:20,134 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:53:32,098 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12601 new items since 1706241199.733485
# 2024-01-27 10:53:32,778 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:53:32,779 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:53:46,553 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article TT Show Episode 19 - RTX 4070 Ti SUPER, Radeon RX 7600 XT, Apple Vision Pro, Meta AI, and more!
# 2024-01-27 10:53:46,555 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241226.555934
# 2024-01-27 10:53:46,963 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:53:58,283 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12601 new items since 1706241226.555934
# 2024-01-27 10:53:59,066 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article already included:
#
# Get over 40 marketing courses for $40
# Now you can learn at your own pace. - mashable.com
# 2024-01-27 10:53:59,066 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:53:59,067 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:54:10,368 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Get over 40 marketing courses for $40
# 2024-01-27 10:54:33,861 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Daily Search Forum Recap: January 26, 2024
# 2024-01-27 10:54:33,863 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241273.8633091
# 2024-01-27 10:54:34,269 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:54:46,144 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12600 new items since 1706241273.8633091
# 2024-01-27 10:54:46,781 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:54:46,782 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 10:55:13,827 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article NASA Announces End of History-making Mars Helicopter Mission
# 2024-01-27 10:55:13,830 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241313.8304021
# 2024-01-27 10:55:14,318 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 10:55:26,985 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 
- app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12585 new items since 1706241550.7476559
# 2024-01-27 10:59:52,336 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Classics of Lesbian Cinema in “Sapph-O-Rama”
# 2024-01-27 11:00:24,474 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article There Is No Shortage Of Great Female-Directed Films
# 2024-01-27 11:00:24,477 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241624.4778051
# 2024-01-27 11:00:24,926 - app.cache.redis.aio_redis_cache - DEBUG - Found 59466 keys in the cache
# 2024-01-27 11:00:38,489 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12548 new items since 1706241624.4778051
# 2024-01-27 11:00:39,183 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:00:39,185 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:00:55,544 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article How Streamlining Environmental Compliance Drives Sustainable Product Development
# 2024-01-27 11:01:21,988 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Can’t stand tags and tight waistbands? Try sensory-friendly clothing
# 2024-01-27 11:01:21,991 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241681.991501
# 2024-01-27 11:01:22,390 - app.cache.redis.aio_redis_cache - DEBUG - Found 59542 keys in the cache
# 2024-01-27 11:01:34,413 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12612 new items since 1706241681.991501
# 2024-01-27 11:01:35,122 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:01:35,122 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:01:52,089 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Farmers Vow To Besiege Paris To Win Govt Concessions
# 2024-01-27 11:01:52,091 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241712.091841
# 2024-01-27 11:01:52,485 - app.cache.redis.aio_redis_cache - DEBUG - Found 59580 keys in the cache
# 2024-01-27 11:02:04,374 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12646 new items since 1706241712.091841
# 2024-01-27 11:02:05,161 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:02:05,162 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:02:05,162 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article already included:
#
# Get over 40 marketing courses for $40
# Now you can learn at your own pace. - mashable.com
# 2024-01-27 11:02:16,538 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Summarized article Fears As Homeschooling Rates 'Surge' In England
# 2024-01-27 11:02:16,541 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Fetching new items since 1706241736.541566
# 2024-01-27 11:02:16,929 - app.cache.redis.aio_redis_cache - DEBUG - Found 59580 keys in the cache
# 2024-01-27 11:02:28,120 - app.core.newsletter_creator.logging_utils - DEBUG - ni--1: Retrieved 12643 new items since 1706241736.541566
# 2024-01-27 11:02:28,753 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:02:28,754 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Boost for Biden as US inflation dips
# Also in this newsletter: Musk's challenge to OpenAI, LVMH boosts luxury sector, science round-up - www.ft.com
# 2024-01-27 11:02:28,754 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Honor Magic V2 Steps Outside China With the Thinnest Inward Foldable Design
# Honor Magic V2 made its official debut in China in July of last year. Until now, the foldable phone remained exclusive to the Chinese market. ... The post Honor Magic V2 Steps Outside China With the Thinnest Inward Foldable Design appeared first on Gizchina.com.
# 2024-01-27 11:02:28,755 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Samsung Galaxy S24 Series Breaks Pre-order Record For the Galaxy S Lineup
# Samsung unrolled the curtains of the Galaxy S24 series just a week ago. After the official unveiling, the company started to take pre-orders, which will ... The post Samsung Galaxy S24 Series Breaks Pre-order Record For the Galaxy S Lineup appeared first on Gizchina.com.
# 2024-01-27 11:02:28,756 - app.core.newsletter_creator.logging_utils - INFO - ni--1: Article too short:
#
# Everything You Need to Know About Sideloading Apps on iPhone
# For years, iPhones have operated within a walled garden. Users could only install apps from the Apple App Store, which is a point of praise ... The post Everything You Need to Know About Sideloading Apps on iPhone appeared first on Gizchina.com.
